# %%
# Statements: A statement is an instruction that python interpreter can execute.
# 2 types of statements: 1. print statements  2. assignment statements
# if we type a statement in a cell, python executes it and displays the results only if there is any result

# *indentation*: like c and java uses {} to define a block of code, in python code block starts and ends with indentation

# %%
# if, elif, else statements
if 100 < 10:  # collon says that we are starting a block of code
    print('it went through')
else:
    print("it didn't went through")
# Out:
# it didn't went through

# %%
list_1= ['var', 'par', 'kar', 'aar']
if 'aar' in list_1:
    print('welcome guest')
else:
    print('please pay subcription')
# Out:
# welcome guest

# %%
height = 5.46

if height < 5.0:
    print('height is ' +str(height)+ 'feet. He is short')
elif height < 5.5:
    print('Height is ' +str(height)+ 'feet. he is medium')
else:
    print('height is '+str(height)+'feet. he is tall')
# Out:
# Height is 5.46feet. he is medium

# %%
small_sale = []
medium_sale = []
large_sale = []

# %%
sale =10

if sale < 5:
    small_sale.append(sale)
elif sale < 10:
    medium_sale.append(sale)
else:
    large_sale.append(sale)

print('small sale', small_sale)
print('medium_sale', medium_sale)
print('large_sale', large_sale)
# Out:
# small sale []
# medium_sale []
# large_sale [10]
