# %%
# nested for loops
greetings = ['hi', 'hello', 'howdy', 'sup']

x=0
y=0

for word in greetings:
    x= x+1
    for letter in word:
        print(x,letter, word,y)
        y=y+1
# Out:
# 1 h hi 0
# 1 i hi 1
# 2 h hello 2
# 2 e hello 3
# 2 l hello 4
# 2 l hello 5
# 2 o hello 6
# 3 h howdy 7
# 3 o howdy 8
# 3 w howdy 9
# 3 d howdy 10
# 3 y howdy 11
# 4 s sup 12
# 4 u sup 13
# 4 p sup 14

# %%
flavours = ['vanilla', 'butter scotch', 'chocolate']
toopings = ['chocolate chips', 'nuts', 'hot fudge']

for flavaour in flavours:
    for top in toopings:
        print(flavaour, 'with', top)
# Out:
# vanilla with chocolate chips
# vanilla with nuts
# vanilla with hot fudge
# butter scotch with chocolate chips
# butter scotch with nuts
# butter scotch with hot fudge
# chocolate with chocolate chips
# chocolate with nuts
# chocolate with hot fudge
