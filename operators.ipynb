# %%
# Operators in python:
# special symbols in python, that can carry out arithemetic or logical computation
# The value that the operator operates on is called operand
# 7 types of operators in python: 1. arithemetic  2. comparision  3. logical  4. assignment  
# 5. bitwise  6.  identity  7. membership

# %%
# comparision operators
#  = is assigning, == is equal to,  != is not equal to

10 == 10
# Out:
# True

# %%
10 != 50
# Out:
# True

# %%
'a' > 'b'
# Out:
# False

# %%
'b' > 'a'
# Out:
# True

# %%
# arthimetic operators

10/2
# Out:
# 5.0

# %%
10//4 # this is called floor division which rounds our vakue
# Out:
# 2

# %%
2 ** 3 # this is 2 power 3,  2^3
# Out:
# 8

# %%
2^3
# Out:
# 1

# %%
4%3
# modulus operator gives remainder
# Out:
# 1

# %%
5%2 ==0
# Out:
# False

# %%
5%2 == 1
# Out:
# True

# %%
# python follows pemdas - para, exponent, multiply, divison, add, subtract

abs(-5) # gives absolute value
# Out:
# 5

# %%
pow(2,5) # similar to 2 ** 5
# Out:
# 32

# %%
round(143.23433, 2)
# Out:
# 143.23

# %%
import math

# %%
math.ceil(5.1)
# Out:
# 6

# %%
list_1 = [2,2,3,1,3,4,8]
math.fsum(list_1)
# Out:
# 23.0

# %%
math.sqrt(49)
# Out:
# 7.0

# %%
# logical operators also have boolean output
(1>5) and (2>4)
# Out:
# False

# %%
(2>1) and (3<1)
# Out:
# False

# %%
(2>1) and (3<5)
# Out:
# True

# %%
(2>1) or (3>5)
# Out:
# True

# %%
(2==2) and ((1==2)or(2==2))
# Out:
# True

# %%
not(3>5)
# Out:
# True

# %%
# membership opearators are used to find a value within a sequence like a string, list or tupul

# in - true if value is found
# not in - true if value is not found

a = 'var'
'a' in a
# Out:
# True

# %%
a= 'par'
'b' not in a
# Out:
# True

# %%
dist = {1:'hi', 2:'bye'}
#1 in dist
'hi' in dist.values()
# Out:
# True

# %%
# assignment operators
a = 5
a = a+5
print (a)
# Out:
# 10

# %%
a =5
a+=5
print(a)
# Out:
# 10

# %%
# identity operators: used to check memory of a variable, not value of it
x = [1,8, 'love']
y = [1,8, 'love']
z=x

# %%
x is z
# Out:
# True

# %%
x is y
# Out:
# False

# %%
x==y
# Out:
# True
